# %%
import pandas as pd

# %%
import numpy as np

# %%
mydata=pd.read_csv(r"C:\Users\lenovo\Desktop\data.csv")

# %%
X_Feature=mydata[["Quants","Reasoning","English","PI","GD"]]

# %%
Y_Feature=mydata["Placed?"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_Feature,Y_Feature,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
PlacementPrediction=LinearRegression()

# %%
PlacementPrediction.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
value_coefficient=PlacementPrediction.coef_

# %%
coeffi_dataframe=pd.DataFrame(value_coefficient,X_Feature.columns,columns=["coefficient"])

# %%
coeffi_dataframe
# Out:
#            coefficient
# Quants       -0.005172
# Reasoning    -0.005185
# English      -0.005190
# PI           -0.005195
# GD           -0.005177

# %%
Y_prediction=PlacementPrediction.predict(X_test)

# %%
Y_prediction
# Out:
# array([1.11884962, 2.00824367, 1.72285107, ..., 2.12497229, 1.69730059,
#        1.81266297])

# %%
result=pd.DataFrame({"Actual":Y_test,"Prediction":Y_prediction})

# %%
result
# Out:
#          Actual  Prediction
# 1031980       1    1.118850
# 531327        2    2.008244
# 23789         2    1.722851
# 402691        2    1.900726
# 953495        2    1.705030
# 944605        1    1.213324
# 788528        1    1.322166
# 788997        2    1.689725
# 659147        2    1.782352
# 107966        2    1.939539
# 1015343       2    2.228912
# 611107        2    1.975002
# 508527        2    1.544019
# 272649        2    1.858810
# 495616        2    2.050068
# 456958        2    1.737989
# 607318        2    2.161429
# 1029932       2    1.564544
# 386199        1    1.513208
# 820201        2    2.122917
# 90691         1    1.460592
# 787364        2    2.118716
# 88995         2    2.072775
# 165917        1    1.217188
# 221019        1    1.139211
# 70821         1    1.068731
# 1018062       2    2.047263
# 81906         2    2.355322
# 934509        2    1.549545
# 138927        2    1.955247
# ...         ...         ...
# 805277        1    1.504909
# 417945        2    1.807402
# 352848        2    2.000029
# 819604        1    1.488010
# 221213        1    1.351651
# 609568        1    1.437843
# 461122        1    1.279510
# 39032         2    1.590832
# 273664        2    2.035360
# 706258        2    1.691975
# 311148        2    1.647205
# 230694        1    1.504693
# 196724        2    1.855587
# 44759         2    1.594353
# 47509         2    1.587262
# 1014724       2    1.933392
# 569682        1    1.097548
# 558083        1    1.004115
# 385682        2    1.843759
# 687103        2    1.936839
# 838087        1    1.469599
# 283370        2    1.634786
# 779517        1    1.145710
# 386385        2    2.299504
# 860936        2    2.321433
# 424472        2    1.547971
# 425138        2    1.549824
# 714687        2    2.124972
# 603545        2    1.697301
# 893429        2    1.812663
#
# [314573 rows x 2 columns]

# %%
from sklearn.externals import joblib
# Output a pickle file for the model
joblib.dump(PlacementPrediction, 'PlacementPrediction.pkl')
# Out:
# ['PlacementPrediction.pkl']
